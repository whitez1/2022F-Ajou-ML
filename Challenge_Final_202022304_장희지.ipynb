# %% [markdown]
# <a href="https://colab.research.google.com/github/whitez1/2022F-Ajou-ML/blob/main/Challenge_Final_202022304_%EC%9E%A5%ED%9D%AC%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge :: Coin Classification

# %% [markdown]
# 여러 나라의 동전 이미지를 보고 어느 나라의 동전인지 분류하는 테스크입니다.
# 동전의 클래스는 인도, 유럽, 중국, 미국, 일본, 필리핀으로 총 6개 입니다.

# %% [markdown]
# 각 나라의 label은 아래와 같이 설정합니다.
# {'china_coins': 0,
#  'euro_coins': 1,
#  'indian_coins': 2,
#  'peso_coins': 3,
#  'us_coins': 4,
#  'yen_coins': 5}

# %% [markdown]
# ## Drive에서 데이터 가져오기 OR 로컬에서 파일 업로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive'
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# '파일_000 (1).png'
#  파일_000.png
#  baseline_ipynb의_사본의_사본.ipynb
#  coins_images2/
#  coins_images3/
# 'Colab Notebooks'/
# 'Remzi H. Arpaci-Dusseau, Andrea C. Arpaci-Dusseau - Operating Systems_ Three Easy Pieces-Arpaci-Dusseau (2015).pdf'

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, utils, datasets
from torch.utils.data import Dataset, DataLoader
import torch.utils.data

# %% [markdown]
# ## Data augmentation

# %%
# From https://hipolarbear.tistory.com/19

import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = 300

file_path = './coins_images2/TRAIN/yen_coins/'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = './coins_images2/TRAIN/yen_coins/' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(file_path + 'inverted_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(file_path + 'rotated_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 3):
        #노이즈 추가하기
        img = cv2.imread(origin_image_path)
        print("noise")
        row,col,ch= img.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy_array = img + gauss
        noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')
        noisy_image.save(file_path + 'noiseAdded_' + str(augment_cnt) + '.png')
        
    augment_cnt += 1
# Out:
# 84
# 67b7a0a2d0.jpg
# ./coins_images2/TRAIN/yen_coins/67b7a0a2d0.jpg
# noise
# 48
# 1cb9361d5b.jpg
# ./coins_images2/TRAIN/yen_coins/1cb9361d5b.jpg
# rotate
# 24
# 3a1bd86807.jpg
# ./coins_images2/TRAIN/yen_coins/3a1bd86807.jpg
# noise
# 28
# 3033e880c0.jpg
# ./coins_images2/TRAIN/yen_coins/3033e880c0.jpg
# invert
# 206
# e3e47162ce.jpg
# ./coins_images2/TRAIN/yen_coins/e3e47162ce.jpg
# invert
# 58
# 12673f3cdf.jpg
# ./coins_images2/TRAIN/yen_coins/12673f3cdf.jpg
# invert
# 113
# a933a8bcc6.jpg
# ./coins_images2/TRAIN/yen_coins/a933a8bcc6.jpg
# invert
# 23
# 32f018be10.jpg
# ./coins_images2/TRAIN/yen_coins/32f018be10.jpg
# noise
# 186
# abcae9339c.jpg
# ./coins_images2/TRAIN/yen_coins/abcae9339c.jpg
# invert
# 113
# a933a8bcc6.jpg
# ./coins_images2/TRAIN/yen_coins/a933a8bcc6.jpg
# invert
# 106
# 55d6279c35.jpg
# ./coins_images2/TRAIN/yen_coins/55d6279c35.jpg
# noise
# 92
# 65a4843235.jpg
# ./coins_images2/TRAIN/yen_coins/65a4843235.jpg
# rotate
# 186
# abcae9339c.jpg
# ./coins_images2/TRAIN/yen_coins/abcae9339c.jpg
# invert
# 59
# 141ba0ed24.jpg
# ./coins_images2/TRAIN/yen_coins/141ba0ed24.jpg
# invert
# 62
# 0f89a0e53d.jpg
# ./coins_images2/TRAIN/yen_coins/0f89a0e53d.jpg
# invert
# 174
# af8934a76c.jpg
# ./coins_images2/TRAIN/yen_coins/af8934a76c.jpg
# invert
# 74
# 7b2fcb5dfc.jpg
# ./coins_images2/TRAIN/yen_coins/7b2fcb5dfc.jpg
# invert
# 13
# 417bff4cc6.jpg
# ./coins_images2/TRAIN/yen_coins/417bff4cc6.jpg
# invert
# 48
# 1cb9361d5b.jpg
# ./coins_images2/TRAIN/yen_coins/1cb9361d5b.jpg
# rotate
# 49
# 182209e67d.jpg
# ./coins_images2/TRAIN/yen_coins/182209e67d.jpg
# noise
# 33
# 251d54716b.jpg
# ./coins_images2/TRAIN/yen_coins/251d54716b.jpg
# noise
# 120
# 93957ef097.jpg
# ./coins_images2/TRAIN/yen_coins/93957ef097.jpg
# rotate
# 198
# fb6f6573b6.jpg
# ./coins_images2/TRAIN/yen_coins/fb6f6573b6.jpg
# rotate
# 143
# 839e3d00d2.jpg
# ./coins_images2/TRAIN/yen_coins/839e3d00d2.jpg
# noise
# 37
# 24fb7d282d.jpg
# ./coins_images2/TRAIN/yen_coins/24fb7d282d.jpg
# invert
# 163
# cd2e240bb3.jpg
# ./coins_images2/TRAIN/yen_coins/cd2e240bb3.jpg
# rotate
# 112
# 475538da33.jpg
# ./coins_images2/TRAIN/yen_coins/475538da33.jpg
# rotate
# 167
# c5dfbefe4c.jpg
# ./coins_images2/TRAIN/yen_coins/c5dfbefe4c.jpg
# invert
# 45
# 1c1c268cb8.jpg
# ./coins_images2/TRAIN/yen_coins/1c1c268cb8.jpg
# rotate
# 42
# 1dc7bf8b63.jpg
# ./coins_images2/TRAIN/yen_coins/1dc7bf8b63.jpg
# rotate
# 37
# 24fb7d282d.jpg
# ./coins_images2/TRAIN/yen_coins/24fb7d282d.jpg
# noise
# 132
# 8a86e0f116.jpg
# ./coins_images2/TRAIN/yen_coins/8a86e0f116.jpg
# noise
# 128
# 8cdf5272cc.jpg
# ./coins_images2/TRAIN/yen_coins/8cdf5272cc.jpg
# rotate
# 49
# 182209e67d.jpg
# ./coins_images2/TRAIN/yen_coins/182209e67d.jpg
# rotate
# 148
# 7f4f7dec71.jpg
# ./coins_images2/TRAIN/yen_coins/7f4f7dec71.jpg
# invert
# 190
# fe3d6dfd45.jpg
# ./coins_images2/TRAIN/yen_coins/fe3d6dfd45.jpg
# invert
# 169
# c49591d0c4.jpg
# ./coins_images2/TRAIN/yen_coins/c49591d0c4.jpg
# invert
# 173
# b5fd7ac418.jpg
# ./coins_images2/TRAIN/yen_coins/b5fd7ac418.jpg
# invert
# 202
# e7279b8af6.jpg
# ./coins_images2/TRAIN/yen_coins/e7279b8af6.jpg
# invert
# 112
# 475538da33.jpg
# ./coins_images2/TRAIN/yen_coins/475538da33.jpg
# rotate
# 119
# 9c14bd0aac.jpg
# ./coins_images2/TRAIN/yen_coins/9c14bd0aac.jpg
# invert
# 27
# 31cd909cf4.jpg
# ./coins_images2/TRAIN/yen_coins/31cd909cf4.jpg
# rotate
# 69
# 03e6960b68.jpg
# ./coins_images2/TRAIN/yen_coins/03e6960b68.jpg
# rotate
# 199
# ec10ef3991.jpg
# ./coins_images2/TRAIN/yen_coins/ec10ef3991.jpg
# invert
# 52
# 17a0e9bfc9.jpg
# ./coins_images2/TRAIN/yen_coins/17a0e9bfc9.jpg
# noise
# 191
# f153d05712.jpg
# ./coins_images2/TRAIN/yen_coins/f153d05712.jpg
# invert
# 38
# 23c840f179.jpg
# ./coins_images2/TRAIN/yen_coins/23c840f179.jpg
# rotate
# 148
# 7f4f7dec71.jpg
# ./coins_images2/TRAIN/yen_coins/7f4f7dec71.jpg
# noise
# 36
# 24bdd6a6de.jpg
# ./coins_images2/TRAIN/yen_coins/24bdd6a6de.jpg
# invert
# 50
# edad3bceac.jpg
# ./coins_images2/TRAIN/yen_coins/edad3bceac.jpg
# noise
# 100
# 5881e3dd7c.jpg
# ./coins_images2/TRAIN/yen_coins/5881e3dd7c.jpg
# rotate
# 204
# e5a16909cd.jpg
# ./coins_images2/TRAIN/yen_coins/e5a16909cd.jpg
# noise
# 157
# cff7ba9cf9.jpg
# ./coins_images2/TRAIN/yen_coins/cff7ba9cf9.jpg
# rotate
# 191
# f153d05712.jpg
# ./coins_images2/TRAIN/yen_coins/f153d05712.jpg
# rotate
# 37
# 24fb7d282d.jpg
# ./coins_images2/TRAIN/yen_coins/24fb7d282d.jpg
# invert
# 22
# 3b81b8aba5.jpg
# ./coins_images2/TRAIN/yen_coins/3b81b8aba5.jpg
# invert
# 13
# 417bff4cc6.jpg
# ./coins_images2/TRAIN/yen_coins/417bff4cc6.jpg
# invert
# 30
# 25bf0c689d.jpg
# ./coins_images2/TRAIN/yen_coins/25bf0c689d.jpg
# noise
# 95
# 5b1fe4a5e1.jpg
# ./coins_images2/TRAIN/yen_coins/5b1fe4a5e1.jpg
# invert
# 175
# b54a0212e3.jpg
# ./coins_images2/TRAIN/yen_coins/b54a0212e3.jpg
# invert
# 41
# 2007984e1f.jpg
# ./coins_images2/TRAIN/yen_coins/2007984e1f.jpg
# noise
# 79
# 7870cce3a1.jpg
# ./coins_images2/TRAIN/yen_coins/7870cce3a1.jpg
# noise
# 54
# 1591723965.jpg
# ./coins_images2/TRAIN/yen_coins/1591723965.jpg
# noise
# 32
# 2822887d98.jpg
# ./coins_images2/TRAIN/yen_coins/2822887d98.jpg
# invert
# 20
# 3c32d6816f.jpg
# ./coins_images2/TRAIN/yen_coins/3c32d6816f.jpg
# noise
# 89
# 65edb1d540.jpg
# ./coins_images2/TRAIN/yen_coins/65edb1d540.jpg
# rotate
# 39
# 232c6beb27.jpg
# ./coins_images2/TRAIN/yen_coins/232c6beb27.jpg
# rotate
# 92
# 65a4843235.jpg
# ./coins_images2/TRAIN/yen_coins/65a4843235.jpg
# rotate
# 167
# c5dfbefe4c.jpg
# ./coins_images2/TRAIN/yen_coins/c5dfbefe4c.jpg
# noise
# 22
# 3b81b8aba5.jpg
# ./coins_images2/TRAIN/yen_coins/3b81b8aba5.jpg
# rotate
# 190
# fe3d6dfd45.jpg
# ./coins_images2/TRAIN/yen_coins/fe3d6dfd45.jpg
# rotate
# 179
# b9aafe65d8.jpg
# ./coins_images2/TRAIN/yen_coins/b9aafe65d8.jpg
# invert
# 116
# 9d80f0cbaf.jpg
# ./coins_images2/TRAIN/yen_coins/9d80f0cbaf.jpg
# rotate
# 50
# edad3bceac.jpg
# ./coins_images2/TRAIN/yen_coins/edad3bceac.jpg
# invert
# 173
# b5fd7ac418.jpg
# ./coins_images2/TRAIN/yen_coins/b5fd7ac418.jpg
# invert
# 136
# 8834ee51da.jpg
# ./coins_images2/TRAIN/yen_coins/8834ee51da.jpg
# rotate
# 183
# a11e78a456.jpg
# ./coins_images2/TRAIN/yen_coins/a11e78a456.jpg
# invert
# 62
# 0f89a0e53d.jpg
# ./coins_images2/TRAIN/yen_coins/0f89a0e53d.jpg
# noise
# 25
# 32739a40f2.jpg
# ./coins_images2/TRAIN/yen_coins/32739a40f2.jpg
# noise
# 100
# 5881e3dd7c.jpg
# ./coins_images2/TRAIN/yen_coins/5881e3dd7c.jpg
# noise
# 133
# 89c3283c43.jpg
# ./coins_images2/TRAIN/yen_coins/89c3283c43.jpg
# rotate
# 2
# 4b1611d015.jpg
# ./coins_images2/TRAIN/yen_coins/4b1611d015.jpg
# invert
# 13
# 417bff4cc6.jpg
# ./coins_images2/TRAIN/yen_coins/417bff4cc6.jpg
# invert
# 202
# e7279b8af6.jpg
# ./coins_images2/TRAIN/yen_coins/e7279b8af6.jpg
# invert
# 68
# 058874b856.jpg
# ./coins_images2/TRAIN/yen_coins/058874b856.jpg
# noise
# 104
# 53ce45a5ad.jpg
# ./coins_images2/TRAIN/yen_coins/53ce45a5ad.jpg
# invert
# 29
# 2ef0e8e52a.jpg
# ./coins_images2/TRAIN/yen_coins/2ef0e8e52a.jpg
# rotate
# 108
# 47bbb23f1a.jpg
# ./coins_images2/TRAIN/yen_coins/47bbb23f1a.jpg
# invert
# 36
# 24bdd6a6de.jpg
# ./coins_images2/TRAIN/yen_coins/24bdd6a6de.jpg
# noise
# 102
# 57ea0eb995.jpg
# ./coins_images2/TRAIN/yen_coins/57ea0eb995.jpg
# noise
# 155
# d7a1fe4bdd.jpg
# ./coins_images2/TRAIN/yen_coins/d7a1fe4bdd.jpg
# noise
# 135
# 8910105010.jpg
# ./coins_images2/TRAIN/yen_coins/8910105010.jpg
# rotate
# 209
# e71b2ee0b7.jpg
# ./coins_images2/TRAIN/yen_coins/e71b2ee0b7.jpg
# rotate
# 140
# 83a8d84b14.jpg
# ./coins_images2/TRAIN/yen_coins/83a8d84b14.jpg
# noise
# 86
# 67b9d07963.jpg
# ./coins_images2/TRAIN/yen_coins/67b9d07963.jpg
# rotate
# 177
# b4a9dcae76.jpg
# ./coins_images2/TRAIN/yen_coins/b4a9dcae76.jpg
# rotate
# 207
# e2cd21fc2c.jpg
# ./coins_images2/TRAIN/yen_coins/e2cd21fc2c.jpg
# noise
# 73
# 7c3cf57a2c.jpg
# ./coins_images2/TRAIN/yen_coins/7c3cf57a2c.jpg
# invert
# 184
# a97e658d9c.jpg
# ./coins_images2/TRAIN/yen_coins/a97e658d9c.jpg
# invert
# 13
# 417bff4cc6.jpg
# ./coins_images2/TRAIN/yen_coins/417bff4cc6.jpg
# rotate
# 184
# a97e658d9c.jpg
# ./coins_images2/TRAIN/yen_coins/a97e658d9c.jpg
# rotate
# 127
# 8eca38d54b.jpg
# ./coins_images2/TRAIN/yen_coins/8eca38d54b.jpg
# noise
# 131
# 89c6f29a65.jpg
# ./coins_images2/TRAIN/yen_coins/89c6f29a65.jpg
# rotate
# 116
# 9d80f0cbaf.jpg
# ./coins_images2/TRAIN/yen_coins/9d80f0cbaf.jpg
# rotate
# 56
# 14021b452a.jpg
# ./coins_images2/TRAIN/yen_coins/14021b452a.jpg
# invert
# 174
# af8934a76c.jpg
# ./coins_images2/TRAIN/yen_coins/af8934a76c.jpg
# noise
# 12
# 3e32ae667c.jpg
# ./coins_images2/TRAIN/yen_coins/3e32ae667c.jpg
# rotate
# 207
# e2cd21fc2c.jpg
# ./coins_images2/TRAIN/yen_coins/e2cd21fc2c.jpg
# rotate
# 71
# 01685f1057.jpg
# ./coins_images2/TRAIN/yen_coins/01685f1057.jpg
# rotate
# 180
# bb4ab48878.jpg
# ./coins_images2/TRAIN/yen_coins/bb4ab48878.jpg
# noise
# 168
# c23f52031b.jpg
# ./coins_images2/TRAIN/yen_coins/c23f52031b.jpg
# invert
# 195
# fb5981d5de.jpg
# ./coins_images2/TRAIN/yen_coins/fb5981d5de.jpg
# noise
# 88
# 6192330d8c.jpg
# ./coins_images2/TRAIN/yen_coins/6192330d8c.jpg
# noise
# 120
# 93957ef097.jpg
# ./coins_images2/TRAIN/yen_coins/93957ef097.jpg
# noise
# 48
# 1cb9361d5b.jpg
# ./coins_images2/TRAIN/yen_coins/1cb9361d5b.jpg
# noise
# 94
# 5e1ea72c72.jpg
# ./coins_images2/TRAIN/yen_coins/5e1ea72c72.jpg
# rotate
# 167
# c5dfbefe4c.jpg
# ./coins_images2/TRAIN/yen_coins/c5dfbefe4c.jpg
# rotate
# 10
# 446904f332.jpg
# ./coins_images2/TRAIN/yen_coins/446904f332.jpg
# noise
# 114
# a46a276558.jpg
# ./coins_images2/TRAIN/yen_coins/a46a276558.jpg
# invert
# 133
# 89c3283c43.jpg
# ./coins_images2/TRAIN/yen_coins/89c3283c43.jpg
# invert
# 9
# 46f9620171.jpg
# ./coins_images2/TRAIN/yen_coins/46f9620171.jpg
# invert
# 148
# 7f4f7dec71.jpg
# ./coins_images2/TRAIN/yen_coins/7f4f7dec71.jpg
# noise
# 80
# 77d310fe4f.jpg
# ./coins_images2/TRAIN/yen_coins/77d310fe4f.jpg
# noise
# 122
# 9743d218ea.jpg
# ./coins_images2/TRAIN/yen_coins/9743d218ea.jpg
# noise
# 34
# 2e6896d8e6.jpg
# ./coins_images2/TRAIN/yen_coins/2e6896d8e6.jpg
# noise
# 130
# 910ecde00b.jpg
# ./coins_images2/TRAIN/yen_coins/910ecde00b.jpg
# rotate
# 53
# 1657f7864e.jpg
# ./coins_images2/TRAIN/yen_coins/1657f7864e.jpg
# rotate
# 160
# d021cacfc8.jpg
# ./coins_images2/TRAIN/yen_coins/d021cacfc8.jpg
# noise
# 52
# 17a0e9bfc9.jpg
# ./coins_images2/TRAIN/yen_coins/17a0e9bfc9.jpg
# rotate
# 30
# 25bf0c689d.jpg
# ./coins_images2/TRAIN/yen_coins/25bf0c689d.jpg
# rotate
# 82
# 69babb7349.jpg
# ./coins_images2/TRAIN/yen_coins/69babb7349.jpg
# invert
# 26
# 26d831ac00.jpg
# ./coins_images2/TRAIN/yen_coins/26d831ac00.jpg
# noise
# 166
# c5f5b8cc36.jpg
# ./coins_images2/TRAIN/yen_coins/c5f5b8cc36.jpg
# noise
# 36
# 24bdd6a6de.jpg
# ./coins_images2/TRAIN/yen_coins/24bdd6a6de.jpg
# rotate
# 97
# 56b11330fa.jpg
# ./coins_images2/TRAIN/yen_coins/56b11330fa.jpg
# noise
# 44
# 1f208af312.jpg
# ./coins_images2/TRAIN/yen_coins/1f208af312.jpg
# rotate
# 164
# ccca72e391.jpg
# ./coins_images2/TRAIN/yen_coins/ccca72e391.jpg
# noise
# 177
# b4a9dcae76.jpg
# ./coins_images2/TRAIN/yen_coins/b4a9dcae76.jpg
# noise
# 92
# 65a4843235.jpg
# ./coins_images2/TRAIN/yen_coins/65a4843235.jpg
# invert
# 126
# 8eb878ba2e.jpg
# ./coins_images2/TRAIN/yen_coins/8eb878ba2e.jpg
# rotate
# 156
# d697497d81.jpg
# ./coins_images2/TRAIN/yen_coins/d697497d81.jpg
# rotate
# 63
# 0971e9de44.jpg
# ./coins_images2/TRAIN/yen_coins/0971e9de44.jpg
# invert
# 49
# 182209e67d.jpg
# ./coins_images2/TRAIN/yen_coins/182209e67d.jpg
# noise
# 37
# 24fb7d282d.jpg
# ./coins_images2/TRAIN/yen_coins/24fb7d282d.jpg
# rotate
# 54
# 1591723965.jpg
# ./coins_images2/TRAIN/yen_coins/1591723965.jpg
# rotate
# 138
# 85e785fb3b.jpg
# ./coins_images2/TRAIN/yen_coins/85e785fb3b.jpg
# noise
# 62
# 0f89a0e53d.jpg
# ./coins_images2/TRAIN/yen_coins/0f89a0e53d.jpg
# invert
# 186
# abcae9339c.jpg
# ./coins_images2/TRAIN/yen_coins/abcae9339c.jpg
# invert
# 206
# e3e47162ce.jpg
# ./coins_images2/TRAIN/yen_coins/e3e47162ce.jpg
# rotate
# 115
# a319848121.jpg
# ./coins_images2/TRAIN/yen_coins/a319848121.jpg
# noise
# 34
# 2e6896d8e6.jpg
# ./coins_images2/TRAIN/yen_coins/2e6896d8e6.jpg
# invert
# 169
# c49591d0c4.jpg
# ./coins_images2/TRAIN/yen_coins/c49591d0c4.jpg
# rotate
# 72
# 807f5448b5.jpg
# ./coins_images2/TRAIN/yen_coins/807f5448b5.jpg
# rotate
# 115
# a319848121.jpg
# ./coins_images2/TRAIN/yen_coins/a319848121.jpg
# noise
# 23
# 32f018be10.jpg
# ./coins_images2/TRAIN/yen_coins/32f018be10.jpg
# invert
# 23
# 32f018be10.jpg
# ./coins_images2/TRAIN/yen_coins/32f018be10.jpg
# rotate
# 177
# b4a9dcae76.jpg
# ./coins_images2/TRAIN/yen_coins/b4a9dcae76.jpg
# noise
# 28
# 3033e880c0.jpg
# ./coins_images2/TRAIN/yen_coins/3033e880c0.jpg
# rotate
# 179
# b9aafe65d8.jpg
# ./coins_images2/TRAIN/yen_coins/b9aafe65d8.jpg
# rotate
# 72
# 807f5448b5.jpg
# ./coins_images2/TRAIN/yen_coins/807f5448b5.jpg
# rotate
# 152
# d8fdf027a8.jpg
# ./coins_images2/TRAIN/yen_coins/d8fdf027a8.jpg
# invert
# 91
# 632a346c3a.jpg
# ./coins_images2/TRAIN/yen_coins/632a346c3a.jpg
# invert
# 189
# ffa5e02e21.jpg
# ./coins_images2/TRAIN/yen_coins/ffa5e02e21.jpg
# noise
# 60
# 05db64f4a6.jpg
# ./coins_images2/TRAIN/yen_coins/05db64f4a6.jpg
# invert
# 1
# 4d27842027.jpg
# ./coins_images2/TRAIN/yen_coins/4d27842027.jpg
# invert
# 41
# 2007984e1f.jpg
# ./coins_images2/TRAIN/yen_coins/2007984e1f.jpg
# invert
# 80
# 77d310fe4f.jpg
# ./coins_images2/TRAIN/yen_coins/77d310fe4f.jpg
# invert
# 44
# 1f208af312.jpg
# ./coins_images2/TRAIN/yen_coins/1f208af312.jpg
# rotate
# 32
# 2822887d98.jpg
# ./coins_images2/TRAIN/yen_coins/2822887d98.jpg
# noise
# 194
# f8934b8498.jpg
# ./coins_images2/TRAIN/yen_coins/f8934b8498.jpg
# invert
# 159
# d7703d09c3.jpg
# ./coins_images2/TRAIN/yen_coins/d7703d09c3.jpg
# rotate
# 82
# 69babb7349.jpg
# ./coins_images2/TRAIN/yen_coins/69babb7349.jpg
# noise
# 195
# fb5981d5de.jpg
# ./coins_images2/TRAIN/yen_coins/fb5981d5de.jpg
# noise
# 19
# 33dee6074e.jpg
# ./coins_images2/TRAIN/yen_coins/33dee6074e.jpg
# invert
# 162
# ce8e1360a1.jpg
# ./coins_images2/TRAIN/yen_coins/ce8e1360a1.jpg
# noise
# 38
# 23c840f179.jpg
# ./coins_images2/TRAIN/yen_coins/23c840f179.jpg
# noise
# 193
# ec9c803ca4.jpg
# ./coins_images2/TRAIN/yen_coins/ec9c803ca4.jpg
# invert
# 61
# 12fa6090a9.jpg
# ./coins_images2/TRAIN/yen_coins/12fa6090a9.jpg
# invert
# 97
# 56b11330fa.jpg
# ./coins_images2/TRAIN/yen_coins/56b11330fa.jpg
# noise
# 186
# abcae9339c.jpg
# ./coins_images2/TRAIN/yen_coins/abcae9339c.jpg
# rotate
# 177
# b4a9dcae76.jpg
# ./coins_images2/TRAIN/yen_coins/b4a9dcae76.jpg
# noise
# 149
# de9fd0d9b2.jpg
# ./coins_images2/TRAIN/yen_coins/de9fd0d9b2.jpg
# invert
# 52
# 17a0e9bfc9.jpg
# ./coins_images2/TRAIN/yen_coins/17a0e9bfc9.jpg
# rotate
# 70
# 08e75a2e06.jpg
# ./coins_images2/TRAIN/yen_coins/08e75a2e06.jpg
# noise
# 16
# 39447d2ec9.jpg
# ./coins_images2/TRAIN/yen_coins/39447d2ec9.jpg
# invert
# 177
# b4a9dcae76.jpg
# ./coins_images2/TRAIN/yen_coins/b4a9dcae76.jpg
# rotate
# 27
# 31cd909cf4.jpg
# ./coins_images2/TRAIN/yen_coins/31cd909cf4.jpg
# noise
# 117
# 9a8b11d5b0.jpg
# ./coins_images2/TRAIN/yen_coins/9a8b11d5b0.jpg
# rotate
# 203
# e68ac14389.jpg
# ./coins_images2/TRAIN/yen_coins/e68ac14389.jpg
# noise
# 11
# 437b494202.jpg
# ./coins_images2/TRAIN/yen_coins/437b494202.jpg
# noise
# 17
# 34b27970d3.jpg
# ./coins_images2/TRAIN/yen_coins/34b27970d3.jpg
# noise
# 194
# f8934b8498.jpg
# ./coins_images2/TRAIN/yen_coins/f8934b8498.jpg
# noise
# 48
# 1cb9361d5b.jpg
# ./coins_images2/TRAIN/yen_coins/1cb9361d5b.jpg
# invert
# 86
# 67b9d07963.jpg
# ./coins_images2/TRAIN/yen_coins/67b9d07963.jpg
# invert
# 161
# d27830b93a.jpg
# ./coins_images2/TRAIN/yen_coins/d27830b93a.jpg
# invert
# 66
# a5bddfdf50.jpg
# ./coins_images2/TRAIN/yen_coins/a5bddfdf50.jpg
# noise
# 208
# e23bc81a64.jpg
# ./coins_images2/TRAIN/yen_coins/e23bc81a64.jpg
# rotate
# 142
# 7defd3bdb7.jpg
# ./coins_images2/TRAIN/yen_coins/7defd3bdb7.jpg
# rotate
# 35
# 254a16b0c8.jpg
# ./coins_images2/TRAIN/yen_coins/254a16b0c8.jpg
# rotate
# 46
# 1b1676cf44.jpg
# ./coins_images2/TRAIN/yen_coins/1b1676cf44.jpg
# noise
# 202
# e7279b8af6.jpg
# ./coins_images2/TRAIN/yen_coins/e7279b8af6.jpg
# invert
# 45
# 1c1c268cb8.jpg
# ./coins_images2/TRAIN/yen_coins/1c1c268cb8.jpg
# invert
# 119
# 9c14bd0aac.jpg
# ./coins_images2/TRAIN/yen_coins/9c14bd0aac.jpg
# rotate
# 179
# b9aafe65d8.jpg
# ./coins_images2/TRAIN/yen_coins/b9aafe65d8.jpg
# noise
# 5
# 4701fbffe3.jpg
# ./coins_images2/TRAIN/yen_coins/4701fbffe3.jpg
# rotate
# 131
# 89c6f29a65.jpg
# ./coins_images2/TRAIN/yen_coins/89c6f29a65.jpg
# invert
# 151
# de96300ee6.jpg
# ./coins_images2/TRAIN/yen_coins/de96300ee6.jpg
# rotate
# 83
# 752d671b74.jpg
# ./coins_images2/TRAIN/yen_coins/752d671b74.jpg
# rotate
# 36
# 24bdd6a6de.jpg
# ./coins_images2/TRAIN/yen_coins/24bdd6a6de.jpg
# invert
# 198
# fb6f6573b6.jpg
# ./coins_images2/TRAIN/yen_coins/fb6f6573b6.jpg
# invert
# 191
# f153d05712.jpg
# ./coins_images2/TRAIN/yen_coins/f153d05712.jpg
# noise
# 143
# 839e3d00d2.jpg
# ./coins_images2/TRAIN/yen_coins/839e3d00d2.jpg
# noise
# 167
# c5dfbefe4c.jpg
# ./coins_images2/TRAIN/yen_coins/c5dfbefe4c.jpg
# rotate
# 110
# 51b0c438d1.jpg
# ./coins_images2/TRAIN/yen_coins/51b0c438d1.jpg
# rotate
# 40
# 23a4f6cbd5.jpg
# ./coins_images2/TRAIN/yen_coins/23a4f6cbd5.jpg
# noise
# 3
# 47386c894d.jpg
# ./coins_images2/TRAIN/yen_coins/47386c894d.jpg
# noise
# 8
# 46c10b3462.jpg
# ./coins_images2/TRAIN/yen_coins/46c10b3462.jpg
# rotate
# 50
# edad3bceac.jpg
# ./coins_images2/TRAIN/yen_coins/edad3bceac.jpg
# invert
# 187
# a78251f564.jpg
# ./coins_images2/TRAIN/yen_coins/a78251f564.jpg
# noise
# 95
# 5b1fe4a5e1.jpg
# ./coins_images2/TRAIN/yen_coins/5b1fe4a5e1.jpg
# noise
# 83
# 752d671b74.jpg
# ./coins_images2/TRAIN/yen_coins/752d671b74.jpg
# noise
# 140
# 83a8d84b14.jpg
# ./coins_images2/TRAIN/yen_coins/83a8d84b14.jpg
# rotate
# 82
# 69babb7349.jpg
# ./coins_images2/TRAIN/yen_coins/69babb7349.jpg
# noise
# 56
# 14021b452a.jpg
# ./coins_images2/TRAIN/yen_coins/14021b452a.jpg
# noise
# 177
# b4a9dcae76.jpg
# ./coins_images2/TRAIN/yen_coins/b4a9dcae76.jpg
# rotate
# 187
# a78251f564.jpg
# ./coins_images2/TRAIN/yen_coins/a78251f564.jpg
# noise
# 39
# 232c6beb27.jpg
# ./coins_images2/TRAIN/yen_coins/232c6beb27.jpg
# rotate
# 23
# 32f018be10.jpg
# ./coins_images2/TRAIN/yen_coins/32f018be10.jpg
# rotate
# 35
# 254a16b0c8.jpg
# ./coins_images2/TRAIN/yen_coins/254a16b0c8.jpg
# invert
# 41
# 2007984e1f.jpg
# ./coins_images2/TRAIN/yen_coins/2007984e1f.jpg
# rotate
# 84
# 67b7a0a2d0.jpg
# ./coins_images2/TRAIN/yen_coins/67b7a0a2d0.jpg
# rotate
# 40
# 23a4f6cbd5.jpg
# ./coins_images2/TRAIN/yen_coins/23a4f6cbd5.jpg
# rotate
# 21
# 3c02c31de1.jpg
# ./coins_images2/TRAIN/yen_coins/3c02c31de1.jpg
# invert
# 36
# 24bdd6a6de.jpg
# ./coins_images2/TRAIN/yen_coins/24bdd6a6de.jpg
# noise
# 87
# 665b1c95bc.jpg
# ./coins_images2/TRAIN/yen_coins/665b1c95bc.jpg
# rotate
# 124
# 96f736f54f.jpg
# ./coins_images2/TRAIN/yen_coins/96f736f54f.jpg
# noise
# 98
# 5a93f5b090.jpg
# ./coins_images2/TRAIN/yen_coins/5a93f5b090.jpg
# noise
# 209
# e71b2ee0b7.jpg
# ./coins_images2/TRAIN/yen_coins/e71b2ee0b7.jpg
# invert
# 4
# 4979a0b5f7.jpg
# ./coins_images2/TRAIN/yen_coins/4979a0b5f7.jpg
# rotate
# 112
# 475538da33.jpg
# ./coins_images2/TRAIN/yen_coins/475538da33.jpg
# noise
# 43
# 2398be4f4e.jpg
# ./coins_images2/TRAIN/yen_coins/2398be4f4e.jpg
# rotate
# 37
# 24fb7d282d.jpg
# ./coins_images2/TRAIN/yen_coins/24fb7d282d.jpg
# noise
# 207
# e2cd21fc2c.jpg
# ./coins_images2/TRAIN/yen_coins/e2cd21fc2c.jpg
# noise
# 103
# 53b366dc83.jpg
# ./coins_images2/TRAIN/yen_coins/53b366dc83.jpg
# rotate
# 185
# aeb3f9ea8b.jpg
# ./coins_images2/TRAIN/yen_coins/aeb3f9ea8b.jpg
# invert
# 57
# 13d366776e.jpg
# ./coins_images2/TRAIN/yen_coins/13d366776e.jpg
# rotate
# 64
# 08925dda9f.jpg
# ./coins_images2/TRAIN/yen_coins/08925dda9f.jpg
# rotate
# 37
# 24fb7d282d.jpg
# ./coins_images2/TRAIN/yen_coins/24fb7d282d.jpg
# invert
# 102
# 57ea0eb995.jpg
# ./coins_images2/TRAIN/yen_coins/57ea0eb995.jpg
# noise
# 69
# 03e6960b68.jpg
# ./coins_images2/TRAIN/yen_coins/03e6960b68.jpg
# invert
# 167
# c5dfbefe4c.jpg
# ./coins_images2/TRAIN/yen_coins/c5dfbefe4c.jpg
# rotate
# 78
# 66b057611c.jpg
# ./coins_images2/TRAIN/yen_coins/66b057611c.jpg
# invert
# 34
# 2e6896d8e6.jpg
# ./coins_images2/TRAIN/yen_coins/2e6896d8e6.jpg
# noise
# 57
# 13d366776e.jpg
# ./coins_images2/TRAIN/yen_coins/13d366776e.jpg
# invert
# 72
# 807f5448b5.jpg
# ./coins_images2/TRAIN/yen_coins/807f5448b5.jpg
# noise
# 204
# e5a16909cd.jpg
# ./coins_images2/TRAIN/yen_coins/e5a16909cd.jpg
# rotate
# 59
# 141ba0ed24.jpg
# ./coins_images2/TRAIN/yen_coins/141ba0ed24.jpg
# rotate
# 180
# bb4ab48878.jpg
# ./coins_images2/TRAIN/yen_coins/bb4ab48878.jpg
# noise
# 69
# 03e6960b68.jpg
# ./coins_images2/TRAIN/yen_coins/03e6960b68.jpg
# noise
# 117
# 9a8b11d5b0.jpg
# ./coins_images2/TRAIN/yen_coins/9a8b11d5b0.jpg
# invert
# 127
# 8eca38d54b.jpg
# ./coins_images2/TRAIN/yen_coins/8eca38d54b.jpg
# invert
# 62
# 0f89a0e53d.jpg
# ./coins_images2/TRAIN/yen_coins/0f89a0e53d.jpg
# invert
# 112
# 475538da33.jpg
# ./coins_images2/TRAIN/yen_coins/475538da33.jpg
# noise
# 71
# 01685f1057.jpg
# ./coins_images2/TRAIN/yen_coins/01685f1057.jpg
# rotate
# 77
# 710de9a8fa.jpg
# ./coins_images2/TRAIN/yen_coins/710de9a8fa.jpg
# noise
# 84
# 67b7a0a2d0.jpg
# ./coins_images2/TRAIN/yen_coins/67b7a0a2d0.jpg
# noise
# 91
# 632a346c3a.jpg
# ./coins_images2/TRAIN/yen_coins/632a346c3a.jpg
# invert
# 9
# 46f9620171.jpg
# ./coins_images2/TRAIN/yen_coins/46f9620171.jpg
# noise
# 2
# 4b1611d015.jpg
# ./coins_images2/TRAIN/yen_coins/4b1611d015.jpg
# invert
# 184
# a97e658d9c.jpg
# ./coins_images2/TRAIN/yen_coins/a97e658d9c.jpg
# invert
# 90
# 6062dd6aa4.jpg
# ./coins_images2/TRAIN/yen_coins/6062dd6aa4.jpg
# rotate
# 48
# 1cb9361d5b.jpg
# ./coins_images2/TRAIN/yen_coins/1cb9361d5b.jpg
# invert
# 154
# d7e0a8e629.jpg
# ./coins_images2/TRAIN/yen_coins/d7e0a8e629.jpg
# rotate
# 116
# 9d80f0cbaf.jpg
# ./coins_images2/TRAIN/yen_coins/9d80f0cbaf.jpg
# rotate
# 76
# 79a88cbcc1.jpg
# ./coins_images2/TRAIN/yen_coins/79a88cbcc1.jpg
# invert
# 172
# bead3b82b7.jpg
# ./coins_images2/TRAIN/yen_coins/bead3b82b7.jpg
# rotate
# 63
# 0971e9de44.jpg
# ./coins_images2/TRAIN/yen_coins/0971e9de44.jpg
# noise
# 15
# 3dd52317fa.jpg
# ./coins_images2/TRAIN/yen_coins/3dd52317fa.jpg
# rotate
# 9
# 46f9620171.jpg
# ./coins_images2/TRAIN/yen_coins/46f9620171.jpg
# invert
# 23
# 32f018be10.jpg
# ./coins_images2/TRAIN/yen_coins/32f018be10.jpg
# noise
# 77
# 710de9a8fa.jpg
# ./coins_images2/TRAIN/yen_coins/710de9a8fa.jpg
# invert
# 63
# 0971e9de44.jpg
# ./coins_images2/TRAIN/yen_coins/0971e9de44.jpg
# noise
# 199
# ec10ef3991.jpg
# ./coins_images2/TRAIN/yen_coins/ec10ef3991.jpg
# noise
# 106
# 55d6279c35.jpg
# ./coins_images2/TRAIN/yen_coins/55d6279c35.jpg
# invert
# 16
# 39447d2ec9.jpg
# ./coins_images2/TRAIN/yen_coins/39447d2ec9.jpg
# noise
# 79
# 7870cce3a1.jpg
# ./coins_images2/TRAIN/yen_coins/7870cce3a1.jpg
# rotate
# 201
# e79e1e364c.jpg
# ./coins_images2/TRAIN/yen_coins/e79e1e364c.jpg
# invert
# 68
# 058874b856.jpg
# ./coins_images2/TRAIN/yen_coins/058874b856.jpg
# noise
# 121
# 9742d5e9e3.jpg
# ./coins_images2/TRAIN/yen_coins/9742d5e9e3.jpg
# rotate
# 71
# 01685f1057.jpg
# ./coins_images2/TRAIN/yen_coins/01685f1057.jpg
# rotate
# 1
# 4d27842027.jpg
# ./coins_images2/TRAIN/yen_coins/4d27842027.jpg
# noise
# 174
# af8934a76c.jpg
# ./coins_images2/TRAIN/yen_coins/af8934a76c.jpg
# rotate
# 66
# a5bddfdf50.jpg
# ./coins_images2/TRAIN/yen_coins/a5bddfdf50.jpg
# rotate
# 176
# b4971d4f15.jpg
# ./coins_images2/TRAIN/yen_coins/b4971d4f15.jpg
# invert
# 21
# 3c02c31de1.jpg
# ./coins_images2/TRAIN/yen_coins/3c02c31de1.jpg
# rotate
# 194
# f8934b8498.jpg
# ./coins_images2/TRAIN/yen_coins/f8934b8498.jpg
# noise
# 72
# 807f5448b5.jpg
# ./coins_images2/TRAIN/yen_coins/807f5448b5.jpg
# noise
# 118
# 9f52d4c146.jpg
# ./coins_images2/TRAIN/yen_coins/9f52d4c146.jpg
# noise
# 152
# d8fdf027a8.jpg
# ./coins_images2/TRAIN/yen_coins/d8fdf027a8.jpg
# rotate

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True # prevent truncate error

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Resize((600, 600)),
        transforms.ToTensor(),
        
    ]),
    "test": transforms.Compose([
        transforms.Resize((600, 600)),
        transforms.ToTensor(),
    ])
}

# %%
# From https://gist.github.com/andrewjong/6b02ff237533b3b2c554701fb53d5c4d

class ImageFolderWithPaths(datasets.ImageFolder):
    """Custom dataset that includes image file paths. Extends
    torchvision.datasets.ImageFolder
    """

    # override the __getitem__ method. this is the method that dataloader calls
    def __getitem__(self, index):
        # this is what ImageFolder normally returns 
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        # the image file path
        path = self.imgs[index][0]
        # make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path

# %%
train_data = ImageFolderWithPaths(root = './coins_images3/' + "TRAIN", # load train data
                                   transform = image_transforms['train'],
                                  )
train_loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True) # make train loader

# %%
train_data
# Out:
# Dataset ImageFolderWithPaths
#     Number of datapoints: 1229
#     Root location: ./coins_images3/TRAIN
#     StandardTransform
# Transform: Compose(
#                Resize(size=(600, 600), interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                RandomResizedCrop(size=(600, 600), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)
#            )

# %%
classes = train_data.class_to_idx # class name
classes
# Out:
# {'china_coins': 0,
#  'euro_coins': 1,
#  'indian_coins': 2,
#  'peso_coins': 3,
#  'us_coins': 4,
#  'yen_coins': 5}

# %% [markdown]
# ## Show Example Data

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
# print(dataiter.next())
images, labels, paths = next(dataiter)

batch_size = 16

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print()
labels = labels.tolist()
print(' '.join(f'{list(classes.keys())[list(classes.values()).index(j)]}' for j in labels))
# Out:
# us_coins yen_coins yen_coins indian_coins china_coins us_coins us_coins peso_coins china_coins china_coins peso_coins indian_coins yen_coins euro_coins peso_coins indian_coins

# %% [markdown]
# ## Define a Convolutional Neural Network

# %% [markdown]
# Modified https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        
        ############### Conv2d, MaxPool2d, Linear 함수에 들어갈 파라미터를 채우세요 ##############
        self.conv1 = nn.Conv2d(3, 20, 3) # in_channel, out_channel, kernel size
        self.pool = nn.MaxPool2d(2, 2) # kernel_size, stride
        self.conv2 = nn.Conv2d(20, 40, 3)
        self.fc1 = nn.Linear(876160, 120) # in_features, out_features
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 6)
        ###########################################################################################

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Use GPU if it's available # colab 런타임 유형 변경에서 GPU 선택할 것

# %%
net = Net() # define the network
net = net.to(device) # send the network to the device

# %% [markdown]
# ## Define a Loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss() # loss function, 변경 가능
optimizer = optim.Adam(net.parameters(), lr=0.001)
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9) # optimizer, 변경 가능

# %% [markdown]
# ## Train the Network

# %%
for epoch in range(50):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(tqdm(train_loader, 0)):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels, paths = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 50 == 49:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0

print('Finished Training') # epoch이 50일 때, training acc 46% 달성
# Out:
#   0%|          | 0/77 [00:00<?, ?it/s]
# [1,    50] loss: 0.055
#   0%|          | 0/77 [00:00<?, ?it/s]
# [2,    50] loss: 0.043
#   0%|          | 0/77 [00:00<?, ?it/s]
# [3,    50] loss: 0.031
#   0%|          | 0/77 [00:00<?, ?it/s]
# [4,    50] loss: 0.009
#   0%|          | 0/77 [00:00<?, ?it/s]
# [5,    50] loss: 0.002
#   0%|          | 0/77 [00:00<?, ?it/s]
# [6,    50] loss: 0.001
#   0%|          | 0/77 [00:00<?, ?it/s]
# [7,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [8,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [9,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [10,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [11,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [12,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [13,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [14,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [15,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [16,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [17,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [18,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [19,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [20,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [21,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [22,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [23,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [24,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [25,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [26,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [27,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [28,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [29,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [30,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [31,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [32,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [33,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [34,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [35,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [36,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [37,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [38,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [39,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [40,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [41,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [42,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [43,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [44,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [45,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [46,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [47,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [48,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [49,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [50,    50] loss: 0.000
# Finished Training

# %% [markdown]
# ## Save the Network

# %%
# save the trained model
PATH = './net_pretrained.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# ## Load the Network

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Calculate Training accuracy

# %%
net.cuda() #오류 때문에 추가
train_test_loader = torch.utils.data.DataLoader(train_data, batch_size=1, shuffle=False) # make train_test loader

# %%
correct = 0
total = 0

image_id = []
predicted_label = []
with torch.no_grad(): # since we're not training, we don't need to calculate the gradients for our outputs
    for i, data in enumerate(tqdm(train_test_loader,0)):
        images, labels, paths = data
        images = images.to(device)
        labels = labels.to(device)
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        
        image_id.append(paths)
        predicted_label.append(predicted.item())

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # print('path:', paths, 'predicted_label:', predicted)
print(f'Accuracy of the network on the {len(train_test_loader.dataset)} test images: {100 * correct // total} %')
# Out:
#   0%|          | 0/1229 [00:00<?, ?it/s]
# Accuracy of the network on the 1229 test images: 100 %

# %% [markdown]
# ## Testing & Making a Submission File

# %%
from PIL import Image
import torch
from torch.utils.data import Dataset


class testDataset(Dataset):
    def __init__(self, data_dir, transform):
        # path to images
        path2data = os.path.join(data_dir)

        # get a list of images
        filenames = os.listdir(path2data)

        # get the full path to images
        self.full_filenames = [os.path.join(path2data, f) for f in filenames]
        
        # set transformations
        self.transform = transform

    def __len__(self):
        # return size of dataset
        return len(self.full_filenames)

    def __getitem__(self, idx):
        # open image, apply transforms and return with label
        image = Image.open(self.full_filenames[idx])
        image = self.transform(image)
        image_name = self.full_filenames[idx]
        return image, image_name

# %%
import os
test_data = testDataset('coins_images3/TEST/',image_transforms['test'])
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False) # ALWAYS SET SHUFFLE FALSE

# %%
image_id = []
predicted_label = []
with torch.no_grad(): # since we're not training, we don't need to calculate the gradients for our outputs
    for i, data in enumerate(tqdm(test_loader,0)):
        images, paths = data
        images = images.to(device)

        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        path = os.path.basename(paths[0])
        image_id.append(path)
        predicted_label.append(predicted.item())
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]

# %%
predicted_df = pd.DataFrame({'image_id': image_id, 'predicted_label': predicted_label})

# %%
predicted_df['predicted_label'] = predicted_df.predicted_label.astype(str)

# %%
predicted_df.to_csv('prediction_result.csv', index=False)
